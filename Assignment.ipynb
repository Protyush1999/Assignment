# %% [markdown]
# ## **Task 1:**

# %%
#Import Library
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Loading Dataset Bigbasket
df1=pd.read_excel("/content/drive/MyDrive/Bigbasket 235687 Reviews.xlsx")
df1
# Out:
#                                     reviewId            userName  \
# 0       f793d90d-73dc-4810-9f1c-6f2d6cd4658c         Tanu Sharma
# 1       f8a9f795-01a2-405d-8be2-acedce6ad56d         Mahesh Mahi
# 2       d8d1bed2-4551-4d97-9fec-9fa7464e2e7f        Ramesh Datla
# 3       bee55523-b64c-4420-8889-f08e3bb896a2  swechchha sarojkar
# 4       c7a61b2a-e044-4c2e-9917-fc4a008cefb2        sam shinchan
# ...                                      ...                 ...
# 235682  40b407e0-bbc4-44a8-8768-dabab0d2b814       A Google user
# 235683  b86109f2-418a-4501-b0ef-7ec15e1b9fb5       A Google user
# 235684  e49d5896-2c22-4046-a468-e1b0646300e0       A Google user
# 235685  300344da-2adf-4304-973d-6ae4e7d83c4f       A Google user
# 235686  b7bdfc06-fef0-4210-839a-2ca87abc101e       A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ALm5wu...
# 1       https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %%
#create a list
source=['bb']*len(df1.index)

# %%
#Add source column in df1
df1['Source']=source

# %%
df1.head()
# Out:
#                                reviewId            userName  \
# 0  f793d90d-73dc-4810-9f1c-6f2d6cd4658c         Tanu Sharma
# 1  f8a9f795-01a2-405d-8be2-acedce6ad56d         Mahesh Mahi
# 2  d8d1bed2-4551-4d97-9fec-9fa7464e2e7f        Ramesh Datla
# 3  bee55523-b64c-4420-8889-f08e3bb896a2  swechchha sarojkar
# 4  c7a61b2a-e044-4c2e-9917-fc4a008cefb2        sam shinchan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ALm5wu...
# 1  https://play-lh.googleusercontent.com/a/ALm5wu...
# 2  https://play-lh.googleusercontent.com/a/ALm5wu...
# 3  https://play-lh.googleusercontent.com/a-/ACNPE...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0                Nice but price higher than jio mart      5              0
# 1  good fresh products... Well service... On time...      5              0
# ...

# %%
#Loading Dataset Blinkit
df2=pd.read_excel("/content/drive/MyDrive/Blinkit 267824 Reviews.xlsx")
df2
# Out:
#                                     reviewId             userName  \
# 0       01e789a2-7348-4cf7-9b95-6a825d0dface  Dr Yusuf Khan Tadvi
# 1       a4439e2d-4343-4b73-895f-4c8d7b2aac0e              S KUMAR
# 2       92ccf3ee-d85f-45f3-9294-7dd4d72b50b3         SATYA SHUKLA
# 3       687a1831-d662-438f-9bd6-63e1f47ae1a4        Megha Sangwan
# 4       3f5494d0-4dc5-469c-9ef4-6b31551703c8     TARA DUTT Tiwari
# ...                                      ...                  ...
# 267819  387db420-ff46-4fe3-ad52-1fe3f02da0d1        A Google user
# 267820  9984213b-0def-400f-bee4-7219d4714db2        A Google user
# 267821  7ab16009-f491-403d-8c7a-f2d47a48bb4b        A Google user
# 267822  67cac85b-0064-4e25-bd23-e4c5691278d1        A Google user
# 267823  772313d5-d3e8-482d-86bf-1ace2e7a27e5        A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %%
#create a list
source1=['bl']*len(df2.index)

# %%
#Add source column in df2
df2['Source']=source1

# %%
df2
# Out:
#                                     reviewId             userName  \
# 0       01e789a2-7348-4cf7-9b95-6a825d0dface  Dr Yusuf Khan Tadvi
# 1       a4439e2d-4343-4b73-895f-4c8d7b2aac0e              S KUMAR
# 2       92ccf3ee-d85f-45f3-9294-7dd4d72b50b3         SATYA SHUKLA
# 3       687a1831-d662-438f-9bd6-63e1f47ae1a4        Megha Sangwan
# 4       3f5494d0-4dc5-469c-9ef4-6b31551703c8     TARA DUTT Tiwari
# ...                                      ...                  ...
# 267819  387db420-ff46-4fe3-ad52-1fe3f02da0d1        A Google user
# 267820  9984213b-0def-400f-bee4-7219d4714db2        A Google user
# 267821  7ab16009-f491-403d-8c7a-f2d47a48bb4b        A Google user
# 267822  67cac85b-0064-4e25-bd23-e4c5691278d1        A Google user
# 267823  772313d5-d3e8-482d-86bf-1ace2e7a27e5        A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %%
#Loading dataset Jio Mart
df3=pd.read_excel("/content/drive/MyDrive/Jio Mart 204424 Reviews.xlsx")
df3
# Out:
#                                     reviewId           userName  \
# 0       ccb7f28d-32bc-498b-930e-4cc86eea6932        Vivek Lakum
# 1       0a7f0d2a-3815-46d4-bb5a-202db3ab14d8       Liyakath ali
# 2       0a69b1bf-7c98-41c5-b99f-8a761df2bc79      jagjeet singh
# 3       9e13f501-6154-4b85-a7cb-edcf3a82ee42          Pintu Das
# 4       09c540b1-9e6e-4364-a95d-3f2349e91b01       Chirag Puvar
# ...                                      ...                ...
# 204419  90ad7655-9fb6-4a64-bf6e-7e4d20392643     Birendra Kumar
# 204420  a5161eaa-9a6d-4147-8e68-f7eece9ff76e     Beer Mohamed S
# 204421  5240e4af-d586-427b-8180-8f901132f3d1     Pankaj Chhetri
# 204422  a828cd5c-4c79-44ec-9e30-b2b696275c9f  Sumit Vishwakarma
# 204423  453ab2df-0212-4eba-be71-e1b4f5be6a33       John Manjila
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ALm5wu...
# 1       https://play-lh.googleusercontent.com/a-/ACNPE...
# ...

# %%
#create a list
source2=['jm']*len(df3.index)

# %%
#Add source to df3
df3['Source']=source2

# %%
df3
# Out:
#                                     reviewId           userName  \
# 0       ccb7f28d-32bc-498b-930e-4cc86eea6932        Vivek Lakum
# 1       0a7f0d2a-3815-46d4-bb5a-202db3ab14d8       Liyakath ali
# 2       0a69b1bf-7c98-41c5-b99f-8a761df2bc79      jagjeet singh
# 3       9e13f501-6154-4b85-a7cb-edcf3a82ee42          Pintu Das
# 4       09c540b1-9e6e-4364-a95d-3f2349e91b01       Chirag Puvar
# ...                                      ...                ...
# 204419  90ad7655-9fb6-4a64-bf6e-7e4d20392643     Birendra Kumar
# 204420  a5161eaa-9a6d-4147-8e68-f7eece9ff76e     Beer Mohamed S
# 204421  5240e4af-d586-427b-8180-8f901132f3d1     Pankaj Chhetri
# 204422  a828cd5c-4c79-44ec-9e30-b2b696275c9f  Sumit Vishwakarma
# 204423  453ab2df-0212-4eba-be71-e1b4f5be6a33       John Manjila
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ALm5wu...
# 1       https://play-lh.googleusercontent.com/a-/ACNPE...
# ...

# %%
#All the data frames
df_s=[df1,df2,df3]

# %%
#Merge Dataset
merge_df=pd.concat(df_s)

# %%
merge_df
# Out:
#                                     reviewId            userName  \
# 0       f793d90d-73dc-4810-9f1c-6f2d6cd4658c         Tanu Sharma
# 1       f8a9f795-01a2-405d-8be2-acedce6ad56d         Mahesh Mahi
# 2       d8d1bed2-4551-4d97-9fec-9fa7464e2e7f        Ramesh Datla
# 3       bee55523-b64c-4420-8889-f08e3bb896a2  swechchha sarojkar
# 4       c7a61b2a-e044-4c2e-9917-fc4a008cefb2        sam shinchan
# ...                                      ...                 ...
# 204419  90ad7655-9fb6-4a64-bf6e-7e4d20392643      Birendra Kumar
# 204420  a5161eaa-9a6d-4147-8e68-f7eece9ff76e      Beer Mohamed S
# 204421  5240e4af-d586-427b-8180-8f901132f3d1      Pankaj Chhetri
# 204422  a828cd5c-4c79-44ec-9e30-b2b696275c9f   Sumit Vishwakarma
# 204423  453ab2df-0212-4eba-be71-e1b4f5be6a33        John Manjila
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ALm5wu...
# 1       https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %%
#Export the merge df
merge_df.to_excel("All_reviews.xlsx")

# %%
mydata = merge_df.drop(['reviewId','userImage','thumbsUpCount','reviewCreatedVersion','at','replyContent','repliedAt'],axis=1)
mydata.head()
# Out:
#              userName                                            content  \
# 0         Tanu Sharma                Nice but price higher than jio mart
# 1         Mahesh Mahi  good fresh products... Well service... On time...
# 2        Ramesh Datla  Fast and easy using and ordering. Will wait an...
# 3  swechchha sarojkar  Fake one. If u cancelled an order believe me t...
# 4        sam shinchan  Didn't enjoy shipping nothing I'm really sugge...
#
#    score Source
# 0      5     bb
# 1      5     bb
# 2      4     bb
# 3      1     bb
# 4      1     bb

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 707935 entries, 0 to 204423
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   userName  707935 non-null  object
#  1   content   707884 non-null  object
#  2   score     707935 non-null  int64
#  3   Source    707935 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 27.0+ MB

# %%
mydata = mydata.dropna(axis=0)
mydata
# Out:
#                   userName                                            content  \
# 0              Tanu Sharma                Nice but price higher than jio mart
# 1              Mahesh Mahi  good fresh products... Well service... On time...
# 2             Ramesh Datla  Fast and easy using and ordering. Will wait an...
# 3       swechchha sarojkar  Fake one. If u cancelled an order believe me t...
# 4             sam shinchan  Didn't enjoy shipping nothing I'm really sugge...
# ...                    ...                                                ...
# 204419      Birendra Kumar                                    Great service 👍
# 204420      Beer Mohamed S  Its great App. Extremely easy to order and goo...
# 204421      Pankaj Chhetri           Please integrate this app with MYJio app
# 204422   Sumit Vishwakarma  Very helpful app, especially during lockdown. ...
# 204423        John Manjila               Much awaited, kudos to JioMart team!
#
#         score Source
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 707884 entries, 0 to 204423
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   userName  707884 non-null  object
#  1   content   707884 non-null  object
#  2   score     707884 non-null  int64
#  3   Source    707884 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 27.0+ MB

# %%
import re

# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+| [^0-9]+', ' ', str(text))
    return text

#def clean1(text):
# Removes all special characters and numericals leaving the alphabets
    #text = re.sub('[^0-9]+', ' ',str(text))
    #return text
  

# Cleaning the text in the review column
mydata['Cleaned Reviews'] = mydata['content'].apply(clean)
mydata['cleaned Rating'] = mydata['score'].apply(clean)
mydata.head()
# Out:
#              userName                                            content  \
# 0         Tanu Sharma                Nice but price higher than jio mart
# 1         Mahesh Mahi  good fresh products... Well service... On time...
# 2        Ramesh Datla  Fast and easy using and ordering. Will wait an...
# 3  swechchha sarojkar  Fake one. If u cancelled an order believe me t...
# 4        sam shinchan  Didn't enjoy shipping nothing I'm really sugge...
#
#    score Source                                    Cleaned Reviews  \
# 0      5     bb                Nice but price higher than jio mart
# 1      5     bb  good fresh products Well service On time deliv...
# 2      4     bb  Fast and easy using and ordering Will wait and...
# 3      1     bb  Fake one If u cancelled an order believe me th...
# 4      1     bb  Didn t enjoy shipping nothing I m really sugge...
#
#   cleaned Rating
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Here if we apply this function in the score column . It doesnot work according we need. It cleans all the numeric value.

# %%
import re

# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+/ [^0-9]+', ' ', str(text))
    return text

#def clean1(text):
# Removes all special characters and numericals leaving the alphabets
    #text = re.sub('[^0-9]+', ' ',str(text))
    #return text
  

# Cleaning the text in the review column
mydata['Cleaned Reviews'] = mydata['content'].apply(clean)
mydata['cleaned Rating'] = mydata['score'].apply(clean)
mydata.head()
# Out:
#              userName                                            content  \
# 0         Tanu Sharma                Nice but price higher than jio mart
# 1         Mahesh Mahi  good fresh products... Well service... On time...
# 2        Ramesh Datla  Fast and easy using and ordering. Will wait an...
# 3  swechchha sarojkar  Fake one. If u cancelled an order believe me t...
# 4        sam shinchan  Didn't enjoy shipping nothing I'm really sugge...
#
#    score Source                                    Cleaned Reviews  \
# 0      5     bb                Nice but price higher than jio mart
# 1      5     bb  good fresh products... Well service... On time...
# 2      4     bb  Fast and easy using and ordering. Will wait an...
# 3      1     bb  Fake one. If u cancelled an order believe me t...
# 4      1     bb  Didn't enjoy shipping nothing I'm really sugge...
#
#   cleaned Rating
# 0              5
# 1              5
# 2              4
# 3              1
# 4              1

# %% [markdown]
# Here if we apply this function the content column . It doesnot work according we need. In second row of cleaned Reviews there have some .... But our objective was to clean all of the special characters.

# %% [markdown]
# ## **Task 2:**

# %%
data=pd.read_excel("/content/Sample.xlsx")

# %%
data
# Out:
#     ID            userName                                            content  \
# 0    0         Tanu Sharma                Nice but price higher than jio mart
# 1    1         Mahesh Mahi  good fresh products... Well service... On time...
# 2    2        Ramesh Datla  Fast and easy using and ordering. Will wait an...
# 3    3  swechchha sarojkar  Fake one. If u cancelled an order believe me t...
# 4    4        sam shinchan  Didn't enjoy shipping nothing I'm really sugge...
# 5    5                 NaN                                               Good
# 6    6    Yogesh Bhagoraya                                          Excellent
# 7    7         Naga rathna                                               Good
# 8    8      Mohit Vashisth                                                NaN
# 9    9         rupal patil                          Fast & Best service...!!!
# 10  10     radhika agrawal  Worst app ever. It used to be good but now whe...
# ...

# %%
data.isna().sum()
# Out:
# ID          0
# userName    2
# content     2
# score       2
# dtype: int64

# %%
data.dropna()
# Out:
#     ID            userName                                            content  \
# 0    0         Tanu Sharma                Nice but price higher than jio mart
# 2    2        Ramesh Datla  Fast and easy using and ordering. Will wait an...
# 3    3  swechchha sarojkar  Fake one. If u cancelled an order believe me t...
# 4    4        sam shinchan  Didn't enjoy shipping nothing I'm really sugge...
# 6    6    Yogesh Bhagoraya                                          Excellent
# 7    7         Naga rathna                                               Good
# 9    9         rupal patil                          Fast & Best service...!!!
# 10  10     radhika agrawal  Worst app ever. It used to be good but now whe...
# 12  12     Ram Lal Rustagi                Very convenient and good experience
# 13  13   prabhakar malwade  Available at the time of booking & at the time...
#
#     score
# 0     5.0
# 2     4.0
# 3     1.0
# 4     1.0
# 6     5.0
# 7     5.0
# 9     5.0
# 10    1.0
# ...
